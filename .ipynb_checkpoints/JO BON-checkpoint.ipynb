# %%
import pandas as pd
from plotnine import *
import plotnine as p9
import numpy as np

# %%
Athlete = pd.read_csv("olympic_athletes.csv")
Hote = pd.read_csv("olympic_hosts.csv")
Medaille = pd.read_csv("olympic_medals.csv")
Resultat =  pd.read_csv("olympic_results.csv")

# %%
Athlete.head()
# Out:
#                                          athlete_url       athlete_full_name  \
# 0  https://olympics.com/en/athletes/cooper-woods-...  Cooper WOODS-TOPALOVIC
# 1          https://olympics.com/en/athletes/elofsson          Felix ELOFSSON
# 2     https://olympics.com/en/athletes/dylan-walczyk           Dylan WALCZYK
# 3     https://olympics.com/en/athletes/olli-penttala           Olli PENTTALA
# 4          https://olympics.com/en/athletes/reikherd        Dmitriy REIKHERD
#
#    games_participations        first_game  athlete_year_birth athlete_medals  \
# 0                     1      Beijing 2022              2000.0            NaN
# 1                     2  PyeongChang 2018              1995.0            NaN
# 2                     1      Beijing 2022              1993.0            NaN
# 3                     1      Beijing 2022              1995.0            NaN
# 4                     1      Beijing 2022              1989.0            NaN
#
#    bio
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
Hote = Hote[Hote.game_season == "Summer"]
Hote.head()
# Out:
#       game_slug         game_end_date       game_start_date  game_location  \
# 1    tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z          Japan
# 3      rio-2016  2016-08-21T21:00:00Z  2016-08-05T12:00:00Z         Brazil
# 5   london-2012  2012-08-12T19:00:00Z  2012-07-27T07:00:00Z  Great Britain
# 7  beijing-2008  2008-08-24T12:00:00Z  2008-08-08T00:00:00Z          China
# 9   athens-2004  2004-08-29T18:00:00Z  2004-08-13T06:00:00Z         Greece
#
#       game_name game_season  game_year
# 1    Tokyo 2020      Summer       2020
# 3      Rio 2016      Summer       2016
# 5   London 2012      Summer       2012
# 7  Beijing 2008      Summer       2008
# 9   Athens 2004      Summer       2004

# %%
Medaille = Medaille[(Medaille['country_code']=='DDDE')|(Medaille["country_3_letter_code"] == "GER") | (Medaille["country_3_letter_code"] == "FRG")]
Medaille.head()
# Out:
#      discipline_title     slug_game            event_title event_gender  \
# 35   Freestyle Skiing  beijing-2022      Women's Ski Cross        Women
# 116       Ski Jumping  beijing-2022             Men's Team          Men
# 119       Ski Jumping  beijing-2022    Men's LH Individual          Men
# 123       Ski Jumping  beijing-2022  Women's NH Individual        Women
# 151              Luge  beijing-2022             Team Relay        Mixed
#
#     medal_type participant_type participant_title  \
# 35      BRONZE          Athlete               NaN
# 116     BRONZE         GameTeam           Germany
# 119     BRONZE          Athlete               NaN
# 123     SILVER          Athlete               NaN
# 151       GOLD         GameTeam           Germany
#
#                                            athlete_url  athlete_full_name  \
# 35      https://olympics.com/en/athletes/daniela-maier      Daniela MAIER
# 116                                                NaN                NaN
# 119            https://olympics.com/en/athletes/geiger        Karl GEIGER
# 123  https://olympics.com/en/athletes/katharina-alt...  Katharina ALTHAUS
# 151                                                NaN                NaN
#
#     country_name country_code country_3_letter_code
# 35       Germany           DE                   GER
# 116      Germany           DE                   GER
# 119      Germany           DE                   GER
# 123      Germany           DE                   GER
# 151      Germany           DE                   GER

# %%
Resultat = Resultat[(Resultat["country_3_letter_code"] == "GER") | (Resultat["country_3_letter_code"] == "FRG")| (Resultat["country_code"] == "DDDE")]
Resultat.head()
# Out:
#      discipline_title              event_title     slug_game participant_type  \
# 119  Freestyle Skiing          Men's Ski Cross  beijing-2022          Athlete
# 143  Freestyle Skiing          Men's Ski Cross  beijing-2022          Athlete
# 144  Freestyle Skiing          Men's Ski Cross  beijing-2022          Athlete
# 145  Freestyle Skiing          Men's Ski Cross  beijing-2022          Athlete
# 170  Freestyle Skiing  Women's Freeski Big Air  beijing-2022          Athlete
#
#     medal_type athletes rank_equal rank_position country_name country_code  \
# 119        NaN      NaN      False            32      Germany           DE
# 143        NaN      NaN      False            21      Germany           DE
# 144        NaN      NaN      False            23      Germany           DE
# 145        NaN      NaN      False            14      Germany           DE
# 170        NaN      NaN      False            18      Germany           DE
#
#     country_3_letter_code                                        athlete_url  \
# 119                   GER  https://olympics.com/en/athletes/niklas-bachsl...
# 143                   GER  https://olympics.com/en/athletes/florian-wilms...
# 144                   GER  https://olympics.com/en/athletes/tobias-mueller-1
# 145                   GER  https://olympics.com/en/athletes/daniel-bohnacker
# 170                   GER  https://olympics.com/en/athletes/alia-delia-ei...
#
#         athlete_full_name value_unit value_type
# 119   Niklas BACHSLEITNER        NaN        NaN
# 143     Florian WILMSMANN        NaN        NaN
# 144        Tobias MUELLER        NaN        NaN
# 145      Daniel BOHNACKER        NaN        NaN
# 170  Alia Delia EICHINGER      64.75     POINTS

# %%
#Merge
REHO = pd.merge(Resultat,Hote, left_on='slug_game', right_on='game_slug', how = 'inner')
REHO.head()
# Out:
#   discipline_title                  event_title   slug_game participant_type  \
# 0         Shooting  50m Rifle 3 Positions women  tokyo-2020          Athlete
# 1         Shooting    25m Rapid Fire Pistol Men  tokyo-2020          Athlete
# 2         Shooting    25m Rapid Fire Pistol Men  tokyo-2020          Athlete
# 3         Shooting          10m Air Rifle women  tokyo-2020          Athlete
# 4         Shooting                     Trap Men  tokyo-2020          Athlete
#
#   medal_type athletes rank_equal rank_position country_name country_code  ...  \
# 0        NaN      NaN      False             6      Germany           DE  ...
# 1        NaN      NaN      False             5      Germany           DE  ...
# 2        NaN      NaN      False            13      Germany           DE  ...
# 3        NaN      NaN      False            17      Germany           DE  ...
# 4        NaN      NaN      False            15      Germany           DE  ...
#
#   athlete_full_name value_unit value_type   game_slug         game_end_date  \
# 0        Jolyn BEER        NaN        NaN  tokyo-2020  2021-08-08T14:00:00Z
# 1   Christian REITZ        NaN        NaN  tokyo-2020  2021-08-08T14:00:00Z
# 2       Oliver GEIS        NaN        NaN  tokyo-2020  2021-08-08T14:00:00Z
# 3        Jolyn BEER        NaN        NaN  tokyo-2020  2021-08-08T14:00:00Z
# 4      Andreas LOEW        NaN        NaN  tokyo-2020  2021-08-08T14:00:00Z
#
#         game_start_date game_location   game_name game_season game_year
# 0  2021-07-23T11:00:00Z         Japan  Tokyo 2020      Summer      2020
# 1  2021-07-23T11:00:00Z         Japan  Tokyo 2020      Summer      2020
# 2  2021-07-23T11:00:00Z         Japan  Tokyo 2020      Summer      2020
# 3  2021-07-23T11:00:00Z         Japan  Tokyo 2020      Summer      2020
# 4  2021-07-23T11:00:00Z         Japan  Tokyo 2020      Summer      2020
#
# [5 rows x 22 columns]

# %%
data_medals = REHO[~REHO.medal_type.isnull()]
data_medals

total_medals = []
year = []

for i in range(0,len(Hote)*4+12,4):
    total_medals.append(len(data_medals[data_medals.game_year == (2020 - i)]))
    year.append(2020-i)

medal_country = pd.DataFrame((zip(total_medals, year)), columns = ['Total_medals', 'Year'])

print(medal_country.head())
# Out:
#    Total_medals  Year
# 0            37  2020
# 1            42  2016
# 2            44  2012
# 3            41  2008
# 4            49  2004

# %%
plot = p9.ggplot(data=medal_country,
           mapping=p9.aes(y="Total_medals", x="Year"))
plot + p9.geom_line(color='red') + p9.ggtitle("Répartition des médailles Allemande lors des Jeux Olympiques d'Ete par année")
# Out:
# <ggplot: (170294851723)>

# %% [markdown]
# # 2

# %%
#Athlete total
Athletes = REHO.groupby(by=["game_year"]).size().reset_index(name='athletes_total')
Athletes.head()
# Out:
#    game_year  athletes_total
# 0       1896              88
# 1       1900              60
# 2       1904              61
# 3       1908              78
# 4       1912             126

# %%
plotA = p9.ggplot(data=Athletes,
           mapping=p9.aes(y="athletes_total", x="game_year"))
plotA + p9.geom_line(color='red') + p9.ggtitle("Total Athletes DE")
# Out:
# <ggplot: (170293571847)>

# %%
Homme = Medaille[Medaille["event_gender"] == "Men"]
Homme.head()
# Out:
#     discipline_title     slug_game          event_title event_gender  \
# 116      Ski Jumping  beijing-2022           Men's Team          Men
# 119      Ski Jumping  beijing-2022  Men's LH Individual          Men
# 161             Luge  beijing-2022        Men's Singles          Men
# 241         Skeleton  beijing-2022                  Men          Men
# 243         Skeleton  beijing-2022                  Men          Men
#
#     medal_type participant_type participant_title  \
# 116     BRONZE         GameTeam           Germany
# 119     BRONZE          Athlete               NaN
# 161       GOLD          Athlete               NaN
# 241     SILVER          Athlete               NaN
# 243       GOLD          Athlete               NaN
#
#                                            athlete_url     athlete_full_name  \
# 116                                                NaN                   NaN
# 119            https://olympics.com/en/athletes/geiger           Karl GEIGER
# 161   https://olympics.com/en/athletes/johannes-ludwig       Johannes LUDWIG
# 241        https://olympics.com/en/athletes/axel-jungk            Axel JUNGK
# 243  https://olympics.com/en/athletes/christopher-g...  Christopher GROTHEER
#
#     country_name country_code country_3_letter_code
# 116      Germany           DE                   GER
# 119      Germany           DE                   GER
# 161      Germany           DE                   GER
# 241      Germany           DE                   GER
# 243      Germany           DE                   GER

# %%
dates = []
for value in Homme["slug_game"].values:
    dates.append(int(value.split("-")[-1]))
    
Homme.insert(12, "date", np.array(dates))

# %%
Homme.head()
# Out:
#     discipline_title     slug_game          event_title event_gender  \
# 116      Ski Jumping  beijing-2022           Men's Team          Men
# 119      Ski Jumping  beijing-2022  Men's LH Individual          Men
# 161             Luge  beijing-2022        Men's Singles          Men
# 241         Skeleton  beijing-2022                  Men          Men
# 243         Skeleton  beijing-2022                  Men          Men
#
#     medal_type participant_type participant_title  \
# 116     BRONZE         GameTeam           Germany
# 119     BRONZE          Athlete               NaN
# 161       GOLD          Athlete               NaN
# 241     SILVER          Athlete               NaN
# 243       GOLD          Athlete               NaN
#
#                                            athlete_url     athlete_full_name  \
# 116                                                NaN                   NaN
# 119            https://olympics.com/en/athletes/geiger           Karl GEIGER
# 161   https://olympics.com/en/athletes/johannes-ludwig       Johannes LUDWIG
# 241        https://olympics.com/en/athletes/axel-jungk            Axel JUNGK
# 243  https://olympics.com/en/athletes/christopher-g...  Christopher GROTHEER
#
#     country_name country_code country_3_letter_code  date
# 116      Germany           DE                   GER  2022
# 119      Germany           DE                   GER  2022
# 161      Germany           DE                   GER  2022
# 241      Germany           DE                   GER  2022
# 243      Germany           DE                   GER  2022

# %%
HommeY = Homme.groupby(by="date").event_gender.size().reset_index(name='athletes homme')
HommeY.head()
# Out:
#    date  athletes homme
# 0  1896              13
# 1  1900               7
# 2  1904              15
# 3  1908              12
# 4  1912              22

# %%
plotH = p9.ggplot(data=HommeY,
           mapping=p9.aes(x="date", y="athletes homme"))
plotH + p9.geom_line(color='red') + p9.ggtitle("Total Athletes DE Homme")
# Out:
# <ggplot: (170293560149)>

# %%
Femme = Medaille[Medaille["event_gender"] == "Women"]
Femme.head()
# Out:
#      discipline_title     slug_game            event_title event_gender  \
# 35   Freestyle Skiing  beijing-2022      Women's Ski Cross        Women
# 123       Ski Jumping  beijing-2022  Women's NH Individual        Women
# 163              Luge  beijing-2022        Women's Singles        Women
# 165              Luge  beijing-2022        Women's Singles        Women
# 192          Biathlon  beijing-2022    Women's 4x6km Relay        Women
#
#     medal_type participant_type participant_title  \
# 35      BRONZE          Athlete               NaN
# 123     SILVER          Athlete               NaN
# 163     SILVER          Athlete               NaN
# 165       GOLD          Athlete               NaN
# 192     BRONZE         GameTeam           Germany
#
#                                            athlete_url     athlete_full_name  \
# 35      https://olympics.com/en/athletes/daniela-maier         Daniela MAIER
# 123  https://olympics.com/en/athletes/katharina-alt...     Katharina ALTHAUS
# 163    https://olympics.com/en/athletes/anna-berreiter        Anna BERREITER
# 165  https://olympics.com/en/athletes/natalie-geise...  Natalie GEISENBERGER
# 192                                                NaN                   NaN
#
#     country_name country_code country_3_letter_code
# 35       Germany           DE                   GER
# 123      Germany           DE                   GER
# 163      Germany           DE                   GER
# 165      Germany           DE                   GER
# 192      Germany           DE                   GER

# %%
dates = []
for value in Femme["slug_game"].values:
    dates.append(int(value.split("-")[-1]))
    
Femme.insert(12, "date", np.array(dates))

# %%
FemmeY = Femme.groupby(by="date").event_gender.size().reset_index(name='athletes femme')
FemmeY.head()
# Out:
#    date  athletes femme
# 0  1908               1
# 1  1912               2
# 2  1928               6
# 3  1932               2
# 4  1936              15

# %%
plotF = p9.ggplot(data=FemmeY,
           mapping=p9.aes(x="date", y="athletes femme"))
plotF + p9.geom_line(color='red') + p9.ggtitle("Total Athletes DE Femme")
# Out:
# <ggplot: (170296071690)>

# %%
Mixed = Medaille[Medaille["event_gender"] == "Mixed"]
Mixed.head()
# Out:
#      discipline_title     slug_game          event_title event_gender  \
# 151              Luge  beijing-2022           Team Relay        Mixed
# 221     Alpine Skiing  beijing-2022  Mixed Team Parallel        Mixed
# 961              Judo    tokyo-2020           Mixed Team        Mixed
# 1386          Sailing    tokyo-2020       Nacra 17 Mixed        Mixed
# 1387          Sailing    tokyo-2020       Nacra 17 Mixed        Mixed
#
#      medal_type participant_type participant_title  \
# 151        GOLD         GameTeam           Germany
# 221      SILVER         GameTeam           Germany
# 961      BRONZE         GameTeam           Germany
# 1386     BRONZE         GameTeam           Germany
# 1387     BRONZE         GameTeam           Germany
#
#                                             athlete_url athlete_full_name  \
# 151                                                 NaN               NaN
# 221                                                 NaN               NaN
# 961                                                 NaN               NaN
# 1386     https://olympics.com/en/athletes/paul-kohlhoff     Paul KOHLHOFF
# 1387  https://olympics.com/en/athletes/alica-stuhlemmer  Alica STUHLEMMER
#
#      country_name country_code country_3_letter_code
# 151       Germany           DE                   GER
# 221       Germany           DE                   GER
# 961       Germany           DE                   GER
# 1386      Germany           DE                   GER
# 1387      Germany           DE                   GER

# %%
dates = []
for value in Mixed["slug_game"].values:
    dates.append(int(value.split("-")[-1]))
    
Mixed.insert(12, "date", np.array(dates))

# %%
MixedY = Mixed.groupby(by="date").event_gender.size().reset_index(name='athletes equ')
MixedY.head()
# Out:
#    date  athletes equ
# 0  1908             2
# 1  1912             2
# 2  1936             2
# 3  1952             2
# 4  1960             2

# %%
plotM = p9.ggplot(data=MixedY,
           mapping=p9.aes(x="date", y="athletes equ"))
plotM + p9.geom_line(color='red') + p9.ggtitle("Total Athletes DE Mix")
# Out:
# <ggplot: (170293553366)>

# %%
A.head()
# Out:
#    date  athletes homme  athletes femme
# 0  1896              13             NaN
# 1  1900               7             NaN
# 2  1904              15             NaN
# 3  1908              12             1.0
# 4  1912              22             2.0

# %%
(ggplot(A)
 + geom_line(aes(x='date', y='athletes femme',color="athletes femme"))
 + geom_line(aes(x='date', y='athletes homme', color="athletes homme"))
 + ggtitle('Athletes')
)
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\plotnine\geoms\geom_path.py:75: PlotnineWarning: geom_path: Removed 3 rows containing missing values.
# <ggplot: (170293664491)>
