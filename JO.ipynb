# %%
import pandas as pd
from plotnine import ggplot, geom_point, aes, stat_smooth, facet_wrap
from plotnine.data import mtcars
import plotnine as p9
import matplotlib.pyplot as plt

# %%
Athlete = pd.read_csv("olympic_athletes.csv")
Hote = pd.read_csv("olympic_hosts.csv")
Medaille = pd.read_csv("olympic_medals.csv")
Resultat =  pd.read_csv("olympic_results.csv")

# %%
Athlete
# Out:
#                                              athlete_url  \
# 0      https://olympics.com/en/athletes/cooper-woods-...
# 1              https://olympics.com/en/athletes/elofsson
# 2         https://olympics.com/en/athletes/dylan-walczyk
# 3         https://olympics.com/en/athletes/olli-penttala
# 4              https://olympics.com/en/athletes/reikherd
# ...                                                  ...
# 75899    https://olympics.com/en/athletes/douglas-weigle
# 75900  https://olympics.com/en/athletes/stefania-bertele
# 75901    https://olympics.com/en/athletes/walter-cecconi
# 75902      https://olympics.com/en/athletes/susan-kelley
# 75903  https://olympics.com/en/athletes/andrew-stroukoff
#
#             athlete_full_name  games_participations        first_game  \
# 0      Cooper WOODS-TOPALOVIC                     1      Beijing 2022
# 1              Felix ELOFSSON                     2  PyeongChang 2018
# ...

# %%
HoteS = Hote[Hote.game_season == "Summer"]
HoteS
# Out:
#            game_slug         game_end_date       game_start_date  \
# 1         tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z
# 3           rio-2016  2016-08-21T21:00:00Z  2016-08-05T12:00:00Z
# 5        london-2012  2012-08-12T19:00:00Z  2012-07-27T07:00:00Z
# 7       beijing-2008  2008-08-24T12:00:00Z  2008-08-08T00:00:00Z
# 9        athens-2004  2004-08-29T18:00:00Z  2004-08-13T06:00:00Z
# 11       sydney-2000  2000-10-01T09:00:00Z  2000-09-15T01:00:00Z
# 13      atlanta-1996  1996-08-05T21:00:00Z  1996-07-19T12:00:00Z
# 15    barcelona-1992  1992-08-09T18:00:00Z  1992-07-25T06:00:00Z
# 17        seoul-1988  1988-10-02T10:00:00Z  1988-09-16T22:00:00Z
# 19  los-angeles-1984  1984-08-12T19:00:00Z  1984-07-28T15:00:00Z
# 21       moscow-1980  1980-08-03T18:00:00Z  1980-07-19T05:00:00Z
# 23     montreal-1976  1976-07-31T22:00:00Z  1976-07-17T12:00:00Z
# 25       munich-1972  1972-09-11T19:00:00Z  1972-08-26T07:00:00Z
# ...

# %%
Medaille_DE = Medaille[(Medaille["country_3_letter_code"] == "GER") | (Medaille["country_3_letter_code"] == "FRG")]
Medaille_DE
# Out:
#           discipline_title     slug_game                       event_title  \
# 35        Freestyle Skiing  beijing-2022                 Women's Ski Cross
# 116            Ski Jumping  beijing-2022                        Men's Team
# 119            Ski Jumping  beijing-2022               Men's LH Individual
# 123            Ski Jumping  beijing-2022             Women's NH Individual
# 151                   Luge  beijing-2022                        Team Relay
# ...                    ...           ...                               ...
# 21630  Gymnastics Artistic   athens-1896            team parallel bars men
# 21634  Gymnastics Artistic   athens-1896           team horizontal bar men
# 21636  Gymnastics Artistic   athens-1896                  pommel horse men
# 21651         Cycling Road   athens-1896          individual road race men
# 21688            Wrestling   athens-1896  Unlimited Class, Greco-Roman Men
#
#       event_gender medal_type participant_type participant_title  \
# ...

# %%
Resultat_DE = Resultat[(Resultat["country_3_letter_code"] == "GER") | (Resultat["country_3_letter_code"] == "FRG") ]
Resultat_DE
# Out:
#           discipline_title               event_title         slug_game  \
# 119       Freestyle Skiing           Men's Ski Cross      beijing-2022
# 143       Freestyle Skiing           Men's Ski Cross      beijing-2022
# 144       Freestyle Skiing           Men's Ski Cross      beijing-2022
# 145       Freestyle Skiing           Men's Ski Cross      beijing-2022
# 170       Freestyle Skiing   Women's Freeski Big Air      beijing-2022
# ...                    ...                       ...               ...
# 162639       Alpine Skiing                slalom men  lake-placid-1980
# 162693       Alpine Skiing                slalom men  lake-placid-1980
# 162698  Equestrian Jumping  Jumping Individual mixed     montreal-1976
# 162708  Equestrian Jumping  Jumping Individual mixed     montreal-1976
# 162733  Equestrian Jumping  Jumping Individual mixed     montreal-1976
#
#        participant_type medal_type athletes rank_equal rank_position  \
# ...

# %% [markdown]
# Gra = (p9.ggplot(data=Resultat_DE, mapping=p9.aes(y='slug_game', x='medal_type')))
# Gra + p9.geom_line()+ p9.theme(axis_text_x = p9.element_text(angle=90))

# %%
Athlete_N
# Out:
#          discipline_title                          event_title    slug_game  \
# 12                 Diving    Men's Synchronised 3m Springboard   tokyo-2020
# 13                 Diving  Women's Synchronised 3m Springboard   tokyo-2020
# 24           Canoe Sprint             Men's Canoe Double 1000m   tokyo-2020
# 25           Canoe Sprint                Men's Kayak Four 500m   tokyo-2020
# 26           Canoe Sprint             Men's Kayak Double 1000m   tokyo-2020
# ...                   ...                                  ...          ...
# 4930  Gymnastics Artistic               team parallel bars men  athens-1896
# 4931  Gymnastics Artistic              team horizontal bar men  athens-1896
# 4932  Gymnastics Artistic                     pommel horse men  athens-1896
# 4951         Cycling Road             individual road race men  athens-1896
# 4953            Wrestling     Unlimited Class, Greco-Roman Men  athens-1896
#
#      participant_type medal_type  \
# ...

# %% [markdown]
# Athlete_N = Resultat_DE[Resultat_DE['participant_type']=='Athlete']
# (
#     p9.ggplot(data = Athlete_N, mapping=p9.aes(x="slug_game",y='participant_type'))
#     +p9.geom_line()
# )(
#     p9.ggplot(data = test, mapping=p9.aes(x="index",y='slug_game'))
#     +p9.geom_line()
# )

# %% [markdown]
# test = pd.DataFrame(Athlete_N.slug_game.value_counts())
# test.reset_index(inplace = True)
# print(test.split("-"))

# %%
GenreH = Medaille_DE[Medaille_DE['event_gender']=='Men']
Genre.shape
# Out:
# (446, 12)

# %%
GenreF = Medaille_DE[Medaille_DE['event_gender']=='Women']
Genre.shape
# Out:
# (446, 12)

# %%
#Genders by Games
games = list(HoteS[HoteS['game_season'] == 'Summer']['game_slug'].unique())
#games.sort()
Hommes = []
Femmes = []
for i in games:
    m = Medaille[Medaille['slug_game'] == i]
    Homme = len(m[m.event_gender == 'Men'])
    Hommes.append(Homme)
    Femme = len(m[m.event_gender == 'Women'])
    Femmes.append(Femme)
    

# visualization
+ p9.geom_bar(x=Homme,y=Femmes,color='Fuchsia',alpha = 0.8)
p9.geom_bar(x=Femmes,y=games,color='Red',alpha = 0.8)
ax1.legend(loc='lower right',frameon = False)
ax1.set(xlabel='Gender', ylabel='Games',title = "Summer Olympic Games")

#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 15>()
#      11     Femmes.append(Femme)
#      14 # visualization
# ---> 15 + p9.geom_bar(x=Homme,y=Femmes,color='Fuchsia',alpha = 0.8)
#      16 p9.geom_bar(x=Femmes,y=games,color='Red',alpha = 0.8)
#      17 ax1.legend(loc='lower right',frameon = False)
#
# TypeError: bad operand type for unary +: 'geom_bar'

# %%
data = pd.merge(Resultat_DE, HoteS, left_on="slug_game", right_on="game_slug", how = "inner")

Athlete_N = data[~data.medal_type.isnull()]
data_medals

total_medals = []
year = []

for i in range(0,len(hosts_summer)*4+12,4):
    total_medals.append(len(data_medals[data_medals.game_year == (2020 - i)]))
    year.append(2020-i)

df_medal_country = pd.DataFrame((zip(total_medals, year)), columns = ['Total_medals', 'Year'])

print(df_medal_country.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [69], in <cell line: 4>()
#       1 data = pd.merge(Resultat_DE, HoteS, left_on="slug_game", right_on="game_slug", how = "inner")
#       3 Athlete_N = data[~data.medal_type.isnull()]
# ----> 4 data_medals
#       6 total_medals = []
#       7 year = []
#
# NameError: name 'data_medals' is not defined
