# %%
import pandas as pd
from plotnine import ggplot, aes, geom_histogram
import plotnine as p9
import numpy as np

# %%
Athlete = pd.read_csv("olympic_athletes.csv")
Hote = pd.read_csv("olympic_hosts.csv")
Medaille = pd.read_csv("olympic_medals.csv")
Resultat =  pd.read_csv("olympic_results.csv")

# %%
Athlete.head()
# Out:
#                                          athlete_url       athlete_full_name  \
# 0  https://olympics.com/en/athletes/cooper-woods-...  Cooper WOODS-TOPALOVIC
# 1          https://olympics.com/en/athletes/elofsson          Felix ELOFSSON
# 2     https://olympics.com/en/athletes/dylan-walczyk           Dylan WALCZYK
# 3     https://olympics.com/en/athletes/olli-penttala           Olli PENTTALA
# 4          https://olympics.com/en/athletes/reikherd        Dmitriy REIKHERD
#
#    games_participations        first_game  athlete_year_birth athlete_medals  \
# 0                     1      Beijing 2022              2000.0            NaN
# 1                     2  PyeongChang 2018              1995.0            NaN
# 2                     1      Beijing 2022              1993.0            NaN
# 3                     1      Beijing 2022              1995.0            NaN
# 4                     1      Beijing 2022              1989.0            NaN
#
#    bio
# 0  NaN
# 1  NaN
# 2  NaN
# ...

# %%
Hote = Hote[Hote.game_season == "Summer"]
Hote
# Out:
#            game_slug         game_end_date       game_start_date  \
# 1         tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z
# 3           rio-2016  2016-08-21T21:00:00Z  2016-08-05T12:00:00Z
# 5        london-2012  2012-08-12T19:00:00Z  2012-07-27T07:00:00Z
# 7       beijing-2008  2008-08-24T12:00:00Z  2008-08-08T00:00:00Z
# 9        athens-2004  2004-08-29T18:00:00Z  2004-08-13T06:00:00Z
# 11       sydney-2000  2000-10-01T09:00:00Z  2000-09-15T01:00:00Z
# 13      atlanta-1996  1996-08-05T21:00:00Z  1996-07-19T12:00:00Z
# 15    barcelona-1992  1992-08-09T18:00:00Z  1992-07-25T06:00:00Z
# 17        seoul-1988  1988-10-02T10:00:00Z  1988-09-16T22:00:00Z
# 19  los-angeles-1984  1984-08-12T19:00:00Z  1984-07-28T15:00:00Z
# 21       moscow-1980  1980-08-03T18:00:00Z  1980-07-19T05:00:00Z
# 23     montreal-1976  1976-07-31T22:00:00Z  1976-07-17T12:00:00Z
# 25       munich-1972  1972-09-11T19:00:00Z  1972-08-26T07:00:00Z
# ...

# %%
Medaille = Medaille[(Medaille['country_code']=='DDDE')|(Medaille["country_3_letter_code"] == "GER") | (Medaille["country_3_letter_code"] == "FRG")]
Medaille
# Out:
#           discipline_title     slug_game                       event_title  \
# 35        Freestyle Skiing  beijing-2022                 Women's Ski Cross
# 116            Ski Jumping  beijing-2022                        Men's Team
# 119            Ski Jumping  beijing-2022               Men's LH Individual
# 123            Ski Jumping  beijing-2022             Women's NH Individual
# 151                   Luge  beijing-2022                        Team Relay
# ...                    ...           ...                               ...
# 21630  Gymnastics Artistic   athens-1896            team parallel bars men
# 21634  Gymnastics Artistic   athens-1896           team horizontal bar men
# 21636  Gymnastics Artistic   athens-1896                  pommel horse men
# 21651         Cycling Road   athens-1896          individual road race men
# 21688            Wrestling   athens-1896  Unlimited Class, Greco-Roman Men
#
#       event_gender medal_type participant_type participant_title  \
# ...

# %%
Resultat = Resultat[(Resultat["country_3_letter_code"] == "GER") | (Resultat["country_3_letter_code"] == "FRG")| (Resultat["country_code"] == "DDDE")]
Resultat
# Out:
#           discipline_title               event_title         slug_game  \
# 119       Freestyle Skiing           Men's Ski Cross      beijing-2022
# 143       Freestyle Skiing           Men's Ski Cross      beijing-2022
# 144       Freestyle Skiing           Men's Ski Cross      beijing-2022
# 145       Freestyle Skiing           Men's Ski Cross      beijing-2022
# 170       Freestyle Skiing   Women's Freeski Big Air      beijing-2022
# ...                    ...                       ...               ...
# 162639       Alpine Skiing                slalom men  lake-placid-1980
# 162693       Alpine Skiing                slalom men  lake-placid-1980
# 162698  Equestrian Jumping  Jumping Individual mixed     montreal-1976
# 162708  Equestrian Jumping  Jumping Individual mixed     montreal-1976
# 162733  Equestrian Jumping  Jumping Individual mixed     montreal-1976
#
#        participant_type medal_type athletes rank_equal rank_position  \
# ...

# %%
#Merge
REHO = pd.merge(Resultat,Hote, left_on='slug_game', right_on='game_slug', how = 'inner')
REHO.head()
# Out:
#   discipline_title                  event_title   slug_game participant_type  \
# 0         Shooting  50m Rifle 3 Positions women  tokyo-2020          Athlete
# 1         Shooting    25m Rapid Fire Pistol Men  tokyo-2020          Athlete
# 2         Shooting    25m Rapid Fire Pistol Men  tokyo-2020          Athlete
# 3         Shooting          10m Air Rifle women  tokyo-2020          Athlete
# 4         Shooting                     Trap Men  tokyo-2020          Athlete
#
#   medal_type athletes rank_equal rank_position country_name country_code  ...  \
# 0        NaN      NaN      False             6      Germany           DE  ...
# 1        NaN      NaN      False             5      Germany           DE  ...
# 2        NaN      NaN      False            13      Germany           DE  ...
# 3        NaN      NaN      False            17      Germany           DE  ...
# 4        NaN      NaN      False            15      Germany           DE  ...
#
# ...

# %%
data_medals = REHO[~REHO.medal_type.isnull()]
data_medals

total_medals = []
year = []

for i in range(0,len(Hote)*4+12,4):
    total_medals.append(len(data_medals[data_medals.game_year == (2020 - i)]))
    year.append(2020-i)

medal_country = pd.DataFrame((zip(total_medals, year)), columns = ['Total_medals', 'Year'])

print(medal_country.head())
# Out:
#    Total_medals  Year
# 0            37  2020
# 1            42  2016
# 2            44  2012
# 3            41  2008
# 4            49  2004

# %%
plot = p9.ggplot(data=medal_country,
           mapping=p9.aes(y="Total_medals", x="Year"))
plot + p9.geom_line(color='red') + p9.ggtitle("Répartition des médailles Allemande lors des Jeux Olympiques d'Ete par année")
# Out:
# <ggplot: (137940696733)>

# %% [markdown]
# # 2

# %%
#Athlete total
Athletes = REHO.groupby(by=["game_year"]).size().reset_index(name='athletes')
Athletes
# Out:
#     game_year  athletes
# 0        1896        88
# 1        1900        60
# 2        1904        61
# 3        1908        78
# 4        1912       126
# 5        1928       122
# 6        1932        70
# 7        1936       231
# 8        1952       220
# 9        1956       133
# 10       1960       178
# 11       1964       210
# 12       1968       335
# 13       1972       423
# 14       1976       367
# 15       1980       255
# 16       1984       258
# 17       1988       473
# 18       1992       322
# 19       1996       316
# 20       2000       316
# 21       2004       296
# 22       2008       266
# 23       2012       283
# 24       2016       272
# 25       2020       249

# %%
plotA = p9.ggplot(data=Athletes,
           mapping=p9.aes(y="athletes", x="game_year"))
plotA + p9.geom_line(color='red') + p9.ggtitle("Total Athletes DE")
# Out:
# <ggplot: (137943010585)>

# %%
Homme = Medaille[Medaille["event_gender"] == "Men"]
Homme
# Out:
#           discipline_title     slug_game                       event_title  \
# 116            Ski Jumping  beijing-2022                        Men's Team
# 119            Ski Jumping  beijing-2022               Men's LH Individual
# 161                   Luge  beijing-2022                     Men's Singles
# 241               Skeleton  beijing-2022                               Men
# 243               Skeleton  beijing-2022                               Men
# ...                    ...           ...                               ...
# 21630  Gymnastics Artistic   athens-1896            team parallel bars men
# 21634  Gymnastics Artistic   athens-1896           team horizontal bar men
# 21636  Gymnastics Artistic   athens-1896                  pommel horse men
# 21651         Cycling Road   athens-1896          individual road race men
# 21688            Wrestling   athens-1896  Unlimited Class, Greco-Roman Men
#
#       event_gender medal_type participant_type participant_title  \
# ...

# %%
dates = []
for value in Homme["slug_game"].values:
    dates.append(int(value.split("-")[-1]))
    
Homme.insert(12, "date", np.array(dates))

# %%
Homme
# Out:
#           discipline_title     slug_game                       event_title  \
# 116            Ski Jumping  beijing-2022                        Men's Team
# 119            Ski Jumping  beijing-2022               Men's LH Individual
# 161                   Luge  beijing-2022                     Men's Singles
# 241               Skeleton  beijing-2022                               Men
# 243               Skeleton  beijing-2022                               Men
# ...                    ...           ...                               ...
# 21630  Gymnastics Artistic   athens-1896            team parallel bars men
# 21634  Gymnastics Artistic   athens-1896           team horizontal bar men
# 21636  Gymnastics Artistic   athens-1896                  pommel horse men
# 21651         Cycling Road   athens-1896          individual road race men
# 21688            Wrestling   athens-1896  Unlimited Class, Greco-Roman Men
#
#       event_gender medal_type participant_type participant_title  \
# ...

# %%
HommeY = Homme.groupby(by="date").event_gender.size().reset_index(name='athletes')
HommeY
# Out:
#     date  athletes
# 0   1896        13
# 1   1900         7
# 2   1904        15
# 3   1908        12
# 4   1912        22
# 5   1928        28
# 6   1932        21
# 7   1936        76
# 8   1952        21
# 9   1956        16
# 10  1960        28
# 11  1964        42
# 12  1968        35
# 13  1972        74
# 14  1976        78
# 15  1980        80
# 16  1984        51
# 17  1988        90
# 18  1992        64
# 19  1994        12
# 20  1996        43
# 21  1998         7
# 22  2000        36
# 23  2002        15
# 24  2004        29
# 25  2006        13
# 26  2008        25
# 27  2010        13
# 28  2012        30
# 29  2014         7
# 30  2016        24
# 31  2018        16
# 32  2020        24
# 33  2022        13

# %%
plotH = p9.ggplot(data=HommeY,
           mapping=p9.aes(x="date", y="athletes"))
plotH + p9.geom_line(color='red') + p9.ggtitle("Total Athletes DE Homme")
# Out:
# <ggplot: (137940574666)>

# %%
Femme = Medaille[Medaille["event_gender"] == "Women"]
Femme
# Out:
#        discipline_title       slug_game                   event_title  \
# 35     Freestyle Skiing    beijing-2022             Women's Ski Cross
# 123         Ski Jumping    beijing-2022         Women's NH Individual
# 163                Luge    beijing-2022               Women's Singles
# 165                Luge    beijing-2022               Women's Singles
# 192            Biathlon    beijing-2022           Women's 4x6km Relay
# ...                 ...             ...                           ...
# 19210           Fencing  amsterdam-1928         foil individual women
# 19212           Fencing  amsterdam-1928         foil individual women
# 20345            Tennis  stockholm-1912                 Singles women
# 20620          Swimming  stockholm-1912  4x100m freestyle relay women
# 20965    Figure skating     london-1908              Individual women
#
#       event_gender medal_type participant_type participant_title  \
# ...

# %%
dates = []
for value in Femme["slug_game"].values:
    dates.append(int(value.split("-")[-1]))
    
Femme.insert(12, "date", np.array(dates))

# %%
FemmeY = Femme.groupby(by="date").event_gender.size().reset_index(name='athletes')
FemmeY
# Out:
#     date  athletes
# 0   1908         1
# 1   1912         2
# 2   1928         6
# 3   1932         2
# 4   1936        15
# 5   1952         7
# 6   1956         8
# 7   1960        20
# 8   1964        12
# 9   1968        17
# 10  1972        45
# 11  1976        68
# 12  1980        74
# 13  1984        33
# 14  1988        81
# 15  1992        47
# 16  1994        11
# 17  1996        23
# 18  1998        21
# 19  2000        21
# 20  2002        23
# 21  2004        24
# 22  2006        17
# 23  2008        17
# 24  2010        19
# 25  2012        15
# 26  2014         9
# 27  2016        18
# 28  2018        11
# 29  2020        15
# 30  2022        14

# %%
plotF = p9.ggplot(data=FemmeY,
           mapping=p9.aes(x="date", y="athletes"))
plotF + p9.geom_line(color='red') + p9.ggtitle("Total Athletes DE Femme")
# Out:
# <ggplot: (137935752783)>

# %%
Mixed = Medaille[Medaille["event_gender"] == "Mixed"]
Mixed
# Out:
#       discipline_title                    slug_game             event_title  \
# 151               Luge                 beijing-2022              Team Relay
# 221      Alpine Skiing                 beijing-2022     Mixed Team Parallel
# 961               Judo                   tokyo-2020              Mixed Team
# 1386           Sailing                   tokyo-2020          Nacra 17 Mixed
# 1387           Sailing                   tokyo-2020          Nacra 17 Mixed
# 1714    Figure skating             pyeongchang-2018            Pair Skating
# 1715    Figure skating             pyeongchang-2018            Pair Skating
# 1798              Luge             pyeongchang-2018              Team Relay
# 3144    Figure skating                   sochi-2014             Pairs mixed
# 3145    Figure skating                   sochi-2014             Pairs mixed
# 3203              Luge                   sochi-2014  Mixed Team Relay mixed
# ...

# %%
dates = []
for value in Mixed["slug_game"].values:
    dates.append(int(value.split("-")[-1]))
    
Mixed.insert(12, "date", np.array(dates))

# %%
MixedY = Mixed.groupby(by="date").event_gender.size().reset_index(name='athletes')
MixedY
# Out:
#     date  athletes
# 0   1908         2
# 1   1912         2
# 2   1936         2
# 3   1952         2
# 4   1960         2
# 5   1964         2
# 6   1968         2
# 7   1972         2
# 8   1976         4
# 9   1980         2
# 10  1998         2
# 11  2010         2
# 12  2014         3
# 13  2018         3
# 14  2020         3
# 15  2022         2

# %%
plotM = p9.ggplot(data=MixedY,
           mapping=p9.aes(x="date", y="athletes"))
plotM + p9.geom_line(color='red') + p9.ggtitle("Total Athletes DE Mix")
# Out:
# <ggplot: (137935991492)>

# %%
AthletesAll = pd.merge(FemmeY,HommeY)
AthletesAll
# Out:
# Empty DataFrame
# Columns: [date, athletes]
# Index: []

# %%
del AthletesAll
